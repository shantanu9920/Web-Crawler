# %%
import requests
from bs4 import BeautifulSoup

def fmovies_spider(max_pages):
    page = 1
    while page <= max_pages:
        url = 'https://fmovies.is/most-watched?page='+str(page)
        source_code = requests.get(url)
        plain_text = source_code.text
        soup = BeautifulSoup(plain_text)
        for link in soup.findAll('a', {'class':'name'}):
            href = "https://fmovies.is"+link.get('href')
            title = link.string
            print(title)
            print(href)
            get_fmovies_data(href)
        page += 1
        
def get_fmovies_data(item_url):
    source_code = requests.get(item_url)
    plain_text = source_code.text
    soup = BeautifulSoup(plain_text)
    for item_name in soup.findAll('b'):
        print(item_name.string)
        break
            
fmovies_spider(1)
# Out:
# C:\Users\shantanu kumar\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\shantanu kumar\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# Suicide Squad (Extended Version)
# https://fmovies.is/film/suicide-squad-extended-version.o12j
# 6.2
# Dragon Ball Super
# https://fmovies.is/film/dragon-ball-super.887v
# 8.2
# Now You See Me 2
# https://fmovies.is/film/now-you-see-me-2.855o
# 6.5
# Finding Dory
# https://fmovies.is/film/finding-dory.9558
# 7.4
# Sausage Party (16+)
# https://fmovies.is/film/sausage-party-16.wx76
# 6.3
# Central Intelligence
# https://fmovies.is/film/central-intelligence.9zxm
# 6.8
# The Flash 3
# https://fmovies.is/film/the-flash-3.jvw83
# 8.1
# Game of Thrones 6
# https://fmovies.is/film/game-of-thrones-6.no6n
# 9.5
# X-Men: Apocalypse
# https://fmovies.is/film/x-men-apocalypse.7lr6
# 7.4
# Captain America: Civil War
# https://fmovies.is/film/captain-america-civil-war.8qpv
# 8.2
# Deadpool
# https://fmovies.is/film/deadpool.y5mp
# 8.1
# Boruto: Naruto The Movie
# https://fmovies.is/film/boruto-naruto-the-movie.79my
# 8.5
# The Secret Life of Pets
# https://fmovies.is/film/the-secret-life-of-pets.p1kx
# 6.8
# Bajirao Mastani
# https://fmovies.is/film/bajirao-mastani.q6k5
# 7.2
# The Legend of Tarzan
# https://fmovies.is/film/the-legend-of-tarzan.3mk9
# The Conjuring 2
# https://fmovies.is/film/the-conjuring-2.7556
# The Revenant
# https://fmovies.is/film/the-revenant.w8kk
# Batman v Superman: Dawn of Justice (EXTENDED)
# https://fmovies.is/film/batman-v-superman-dawn-of-justice-extended.3v82
# Jason Bourne
# https://fmovies.is/film/jason-bourne.mxjz
# Don't Breathe
# https://fmovies.is/film/dont-breathe.yqkr1
# The Purge: Election Year
# https://fmovies.is/film/the-purge-election-year.32vr
# The Flash 2
# https://fmovies.is/film/the-flash-2.v48v
# Independence Day: Resurgence
# https://fmovies.is/film/independence-day-resurgence.2qr0
# Teenage Mutant Ninja Turtles: Out of the Shadows
# https://fmovies.is/film/teenage-mutant-ninja-turtles-out-of-the-shadows.96jm
# The Walking Dead 7 (Special)
# https://fmovies.is/film/the-walking-dead-7-special.rl44y
# The Wolf Of Wall Street
# https://fmovies.is/film/the-wolf-of-wall-street.n3ll
# Game Of Thrones 1
# https://fmovies.is/film/game-of-thrones-1.3yl2
# Mechanic: Resurrection
# https://fmovies.is/film/mechanic-resurrection.9pvx
# Warcraft
# https://fmovies.is/film/warcraft.400o
# Ice Age: Collision Course
# https://fmovies.is/film/ice-age-collision-course.1kkx
# Ghostbusters
# https://fmovies.is/film/ghostbusters.p96x
# Lights Out
# https://fmovies.is/film/lights-out.8orv
